# %%
state = 'CA' #input 
df_state = df[df['state'] == state]
selective = ['Selective private', 
             'Four-year for-profit',
       'Selective public',
       'Highly selective private',
       'Other elite schools (public and private)',
       'Highly selective public', 'Ivy Plus']
private = ['Two-year for-profit', 'Selective private',
 'Four-year for-profit',
       'Nonselective four-year private not-for-profit',
       'Highly selective private','Ivy Plus']

selective_list = []
private_list = []
for row in df_state['tier_name']:
    if row in selective:
        selective_list.append(1)
    else:
        selective_list.append(0)
df_state['selective'] = selective_list

for row in df_state['tier_name']:
    if row in private:
        private_list.append(1)
    else:
        private_list.append(0)
df_state['private'] = private_list

n_selective_schools = sum(df_state.selective)
n_graduate = len(df_state[df_state['iclevel'] == 3])
high_graduation_rate = len(df_state[df_state['grad_rate_150_p_2013'] >= .65])
n_private = sum(df_state.private)
# Out:
# <ipython-input-68-228bee9abfaf>:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-68-228bee9abfaf>:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# plotly 
import plotly.express as px

# dashboards
import jupyterlab_dash
import dash
import dash_core_components as dcc
import dash_html_components as html
import dash_table
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
from datetime import date
from dash import html


viewer = jupyterlab_dash.AppViewer()


app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])


first_card = dbc.Card(
    dbc.CardBody(
        [
            html.H5(n_private, className="card-title"),
            html.P("Selective Schools in {}".format(state)),
        ]
    )
)


second_card = dbc.Card(
    dbc.CardBody(
        [
            html.H5(n_graduate, className="card-title"),
            html.P('Graduate Institutions in {}'.format(state) 
            ),
        ]
    )
)

third_card = dbc.Card(
    dbc.CardBody(
        [
            html.H5(n_private, className="card-title"),
            html.P('Private Schools in {}'.format(state)
            ),
        ]
    )
)

fourth_card = dbc.Card(
    dbc.CardBody(
        [
            html.H5(high_graduation_rate, className="card-title"),
            html.P('Schools with High Graduation Rates in {}'.format(state)
            ),
        ]
    )
)

app.layout = dbc.Row(
    [
        dbc.Col(first_card, width=3),
        dbc.Col(second_card, width=3),
        dbc.Col(third_card, width=3),
        dbc.Col(fourth_card, width=3),
    ]
)



# kpis = df.columns[1:]
# app.layout = html.Div([
#     dcc.Dropdown(id='kpi_dropdown',
#                  options=[{'label': kpi, 'value': kpi}
#                           for kpi in kpis]),
#     dcc.Graph(id='kpi_choropleth')
# ])

# @app.callback(
#     Output('kpi_choropleth', 'figure'),
#     Input('kpi_dropdown', 'value'))
# def update_figure(kpi):
#     fig = px.choropleth(df,
#                     locations='State_Code',
#                     color=kpi,
#                     color_continuous_scale='tropic',
#                     hover_name=df.index,
#                     locationmode='USA-states',
#                     title = 'Distribution of {} by State'.format(kpi),
#                     scope='usa')
#     return fig

# Uncomment the following two lines if using Jupyter Notebook
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Dec/2021 22:00:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Dec/2021 22:00:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Dec/2021 22:00:37] "GET /_dash-dependencies HTTP/1.1" 200 -

# %%
import pandas as pd
df = pd.read_csv('mrc_table10.csv')
df.head()
# Out:
#    super_opeid                                             name  region state  \
# 0        30955  ASA Institute Of Business & Computer Technology       1    NY
# 1         3537                     Abilene Christian University       3    TX
# 2         1541             Abraham Baldwin Agricultural College       3    GA
# 3         7531                        Academy Of Art University       4    CA
# 4         1345                           Adams State University       4    CO
#
#    fips     cz         czname  cfips         county    zip  ...  \
# 0    36  19400       New York  36047          Kings  11201  ...
# 1    48  32501        Abilene  48441         Taylor  79699  ...
# 2    13   8503       Valdosta  13277           Tift  31793  ...
# 3     6  37800  San Francisco   6075  San Francisco  94105  ...
# 4     8  34805        Alamosa   8003        Alamosa  81101  ...
#
#    hisp_share_fall_2000 alien_share_fall_2000  pct_arthuman_2000  \
# ...

# %%
state = 'CA' #input 
df_state = df[df['state'] == state]
selective = ['Selective private', 
             'Four-year for-profit',
       'Selective public',
       'Highly selective private',
       'Other elite schools (public and private)',
       'Highly selective public', 'Ivy Plus']
private = ['Two-year for-profit', 'Selective private',
 'Four-year for-profit',
       'Nonselective four-year private not-for-profit',
       'Highly selective private','Ivy Plus']

selective_list = []
private_list = []
for row in df_state['tier_name']:
    if row in selective:
        selective_list.append(1)
    else:
        selective_list.append(0)
df_state['selective'] = selective_list

for row in df_state['tier_name']:
    if row in private:
        private_list.append(1)
    else:
        private_list.append(0)
df_state['private'] = private_list

n_selective_schools = sum(df_state.selective)
graduate = len(df_state[df_state['iclevel'] == 3])
high_graduation_rate = len(df_state[df_state['grad_rate_150_p_2013'] >= .65])
n_private = sum(df_state.private)
# Out:
# <ipython-input-35-caed13f84716>:21: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-35-caed13f84716>:28: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 70

# %%
df_state.columns
# Out:
# Index(['super_opeid', 'name', 'region', 'state', 'fips', 'cz', 'czname',
#        'cfips', 'county', 'zip', 'tier', 'tier_name', 'type', 'iclevel',
#        'public', 'barrons', 'exp_instr_pc_2000', 'exp_instr_pc_2013', 'multi',
#        'hbcu', 'flagship', 'ipeds_enrollment_2013', 'ipeds_enrollment_2000',
#        'sticker_price_2013', 'sticker_price_2000', 'grad_rate_150_p_2013',
#        'grad_rate_150_p_2002', 'avgfacsal_2013', 'avgfacsal_2001',
#        'sat_avg_2013', 'sat_avg_2001', 'scorecard_netprice_2013',
#        'scorecard_rej_rate_2013', 'scorecard_median_earnings_2011',
#        'endowment_pc_2000', 'exp_instr_2012', 'exp_instr_2000',
#        'asian_or_pacific_share_fall_2000', 'black_share_fall_2000',
#        'hisp_share_fall_2000', 'alien_share_fall_2000', 'pct_arthuman_2000',
#        'pct_business_2000', 'pct_health_2000', 'pct_multidisci_2000',
#        'pct_publicsocial_2000', 'pct_stem_2000', 'pct_socialscience_2000',
# ...

# %%
corr_variables = ['tier', 'iclevel', 'grad_rate_150_p_2013', 'avgfacsal_2013','endowment_pc_2000','scorecard_median_earnings_2011',
                  'scorecard_rej_rate_2013', 'selective', 'private']
df_state[corr_variables].corr()
# Out:
#                                     tier   iclevel  grad_rate_150_p_2013  \
# tier                            1.000000  0.765873             -0.535216
# iclevel                         0.765873  1.000000             -0.560027
# grad_rate_150_p_2013           -0.535216 -0.560027              1.000000
# avgfacsal_2013                 -0.736783 -0.286032              0.308292
# endowment_pc_2000              -0.514302 -0.514302              0.611773
# scorecard_median_earnings_2011 -0.829647 -0.730668              0.681503
# scorecard_rej_rate_2013        -0.734562 -0.335251              0.632200
# selective                      -0.744372 -0.844348              0.573427
# private                         0.075621 -0.386367              0.473933
#
#                                 avgfacsal_2013  endowment_pc_2000  \
# tier                                 -0.736783          -0.514302
# iclevel                              -0.286032          -0.514302
# ...

# %%
df_state.tier_name.unique()
# Out:
# array(['Four-year for-profit',
#        'Two-year (public and private not-for-profit)',
#        'Two-year for-profit',
#        'Nonselective four-year private not-for-profit',
#        'Selective private', 'Other elite schools (public and private)',
#        'Selective public', 'Nonselective four-year public',
#        'Less than two-year schools of any type',
#        'Highly selective private', 'Ivy Plus', 'Highly selective public'],
#       dtype=object)

# %%
elite = ['Other elite schools (public and private)',
       'Highly selective private', 'Ivy Plus', 'Highly selective public']
df['elite'] = [1 if x in elite else 0 for x in df['tier_name']]
df['elite'].sum()
# Out:
# 176

# %%
df[df['tier_name'] == 'Selective public']
# Out:
#       super_opeid                                          name  region state  \
# 4            1345                        Adams State University       4    CO
# 14           1002  Alabama Agricultural & Mechanical University       3    AL
# 16           1005                      Alabama State University       3    AL
# 20           1544                       Albany State University       3    GA
# 25           2396                       Alcorn State University       3    MS
# ...           ...                                           ...     ...   ...
# 2432         2986                Winston-Salem State University       3    NC
# 2433         3456                           Winthrop University       3    SC
# 2443         2190                    Worcester State University       1    MA
# 2446         3078                       Wright State University       2    OH
# 2460         3145                   Youngstown State University       2    OH
#
# ...
